# %%
from finlm.tokenizer import FinLMTokenizer

tokenizer = FinLMTokenizer("/home/ralf/language_models/00_tokenizer/finlm-bpe-encoder-tokenizer.json")

tokenizer(["Markets looking bullish this time."])
# Out:
# {'input_ids': [[0, 4703, 3135, 13316, 516, 793, 17]], 'token_type_ids': [[0, 0, 0, 0, 0, 0, 0]], 'attention_mask': [[1, 1, 1, 1, 1, 1, 1]]}
